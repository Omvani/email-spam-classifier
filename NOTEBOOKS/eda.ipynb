# %%
data["label"].value_counts()
# Out:
# label
# 1    8
# 0    7
# Name: count, dtype: int64

# %%
import pandas as pd
data=pd.read_csv("D:/project-2/DATA/e-mail.csv")
print(data.head())
# Out:
#                            email_text  label
# 0           Win money now claim prize      1
# 1               Limited offer buy now      1
# 2      Congratulation you win lottery      1
# 3            Free gift card available      1
# 4  Uregent response required win cash      1
